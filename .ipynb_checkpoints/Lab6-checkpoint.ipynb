# %%
import sys
import collections
import itertools
import numpy as np
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import matplotlib.pyplot as plt
from scipy.stats import mode
from scipy.spatial.distance import squareform

plt.style.use('bmh')
# %matplotlib inline

def dtw_distance(ts_1, ts_2):    
     #ts_1: time serie 1 
     #ts_2: time serie 2
    
    ##TODO: USE fastdtw to calculate disitance between 2 time series
    distance, path = fastdtw(ts_1, ts_2, dist=euclidean)
    return distance
      
    
def dist_matrix(x, y):
    '''x, y are 2 arrays contains many time series '''
    x_s = np.shape(x)
    y_s = np.shape(y)
    dm = np.zeros((x_s[0], y_s[0])) 
    dm_size = x_s[0]*y_s[0]

    ##TODO: calculate distance matrix of 2 time series list/array
    for i in range(0,x_s[0]):
        for j in range(0,y_s[0]):
            print("Distance from " + str(i) + " and " + str(j))
            distance, path = fastdtw(x[i],y[j], dist=euclidean)
            dm[i,j] = distance

    return dm

# %% [markdown]
# ### Calculate and visualize distance btw 2 series

# %%
time = np.linspace(0,20,1000)
amplitude_a = 3*np.cos(time)
amplitude_b = 3*np.sin(time)

distance = dtw_distance(amplitude_a, amplitude_b)

##TODO: Visulize distance matrix of 2 time series

plt.figure(figsize = (10,3))
plt.plot(amplitude_a, label='A')
plt.plot(amplitude_b, label='B')
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.legend()
plt.title("DTW distance between A and B is " + str(distance))
# Out:
# Text(0.5, 1.0, 'DTW distance between A and B is 129.69402983116913')

# %% [markdown]
# ### Test dist_matrix function

# %%
array1 = np.random.random((4,50))
array2 = np.random.random((4,50))     
print(dist_matrix(array1,array2))
# Out:
# Distance from 0 and 0
# Distance from 0 and 1
# Distance from 0 and 2
# Distance from 0 and 3
# Distance from 1 and 0
# Distance from 1 and 1
# Distance from 1 and 2
# Distance from 1 and 3
# Distance from 2 and 0
# Distance from 2 and 1
# Distance from 2 and 2
# Distance from 2 and 3
# Distance from 3 and 0
# Distance from 3 and 1
# Distance from 3 and 2
# Distance from 3 and 3
# [[10.43507727  9.33799836  8.51417023  9.77110601]
#  [ 9.75207877  9.10857134  9.35048559  9.24018366]
#  [ 9.39877075  9.04248926  8.79012153 10.95001253]
#  [ 9.11644975 10.05949388  9.3294847   9.75848652]]

# %% [markdown]
# ### Implement KNN classification

# %%
class KNN(object):
    
    def __init__(self, n_neighbors=5):
        self.n_neighbors = n_neighbors
    
    def fit(self, x, l):
        self.training_x = x
        self.training_label = l

    def predict(self, x):
        ##TODO: identify the k nearest neighbors using dist_matrix
        dm = dist_matrix(x, self.training_x)
        knn_idx = dm.argsort()[:, :self.n_neighbors]
        k = self.n_neighbors
        # Identify k nearest labels
        knn_labels = self.training_label[knn_idx]
        
        # Model Label
        mode_data = mode(knn_labels, axis=1)
        mode_label = mode_data[0]
        mode_proba = mode_data[1]/self.n_neighbors

        return mode_label.ravel(), mode_proba.ravel()

# %% [markdown]
# ## Human Activity Recognition Dataset

# %%
# Import the HAR dataset
x_train_file = open('data/X_train.txt', 'r')
y_train_file = open('data/y_train.txt', 'r')

x_test_file = open('data/X_test.txt', 'r')
y_test_file = open('data/y_test.txt', 'r')

x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# #### Visualizing sample activities from the HAR dataset

# %%
# plt.figure(figsize=(11,7))
colors = ['#1F77B4','#8C564A','#9467BD','#2C9F2C','#D62728',
          '#FD7F23','#7F7F7F','#1FBECF','#E377C2','#BCBD27']

##TODO: Visulize sample activities

for i in range(1,len(labels)+1):
    
    sample_index = np.argmax(y_train == i)
    plt.figure(figsize=(11,4))
    plt.xlim(0, 100)
    plt.xlabel("Samples @50Hz")
    plt.plot(x_train[sample_index], label = labels[i], c=colors[i-1])
    plt.legend()
    plt.show()

# %%
m = KNN(n_neighbors=1)
m.fit(x_train, y_train)
label, proba = m.predict(x_test)
# Out:
# Distance from 0 and 0
# Distance from 0 and 1
# Distance from 0 and 2
# Distance from 0 and 3
# Distance from 0 and 4
# Distance from 0 and 5
# Distance from 0 and 6
# Distance from 0 and 7
# Distance from 0 and 8
# Distance from 0 and 9
# Distance from 0 and 10
# Distance from 0 and 11
# Distance from 0 and 12
# Distance from 0 and 13
# Distance from 0 and 14
# Distance from 0 and 15
# Distance from 0 and 16
# Distance from 0 and 17
# Distance from 0 and 18
# Distance from 0 and 19
# Distance from 0 and 20
# Distance from 0 and 21
# Distance from 0 and 22
# Distance from 0 and 23
# Distance from 0 and 24
# Distance from 0 and 25
# Distance from 0 and 26
# Distance from 0 and 27
# Distance from 0 and 28
# Distance from 0 and 29
# Distance from 0 and 30
# Distance from 0 and 31
# Distance from 0 and 32
# Distance from 0 and 33
# Distance from 0 and 34
# Distance from 0 and 35
# Distance from 0 and 36
# Distance from 0 and 37
# Distance from 0 and 38
# Distance from 0 and 39
# Distance from 0 and 40
# Distance from 0 and 41
# Distance from 0 and 42
# Distance from 0 and 43
# Distance from 0 and 44
# Distance from 0 and 45
# Distance from 0 and 46
# Distance from 0 and 47
# Distance from 0 and 48
# Distance from 0 and 49
# Distance from 0 and 50
# Distance from 0 and 51
# Distance from 0 and 52
# Distance from 0 and 53
# Distance from 0 and 54
# Distance from 0 and 55
# Distance from 0 and 56
# Distance from 0 and 57
# Distance from 0 and 58
# Distance from 0 and 59
# Distance from 0 and 60
# Distance from 0 and 61
# Distance from 0 and 62
# Distance from 0 and 63
# Distance from 0 and 64
# Distance from 0 and 65
# Distance from 0 and 66
# Distance from 0 and 67
# Distance from 0 and 68
# Distance from 0 and 69
# Distance from 0 and 70
# Distance from 0 and 71
# Distance from 0 and 72
# Distance from 0 and 73
# Distance from 0 and 74
# Distance from 0 and 75
# Distance from 0 and 76
# Distance from 0 and 77
# Distance from 0 and 78
# Distance from 0 and 79
# Distance from 0 and 80
# Distance from 0 and 81
# Distance from 0 and 82
# Distance from 0 and 83
# Distance from 0 and 84
# Distance from 0 and 85
# Distance from 0 and 86
# Distance from 0 and 87
# Distance from 0 and 88
# Distance from 0 and 89
# Distance from 1 and 0
# Distance from 1 and 1
# Distance from 1 and 2
# Distance from 1 and 3
# Distance from 1 and 4
# Distance from 1 and 5
# Distance from 1 and 6
# Distance from 1 and 7
# Distance from 1 and 8
# Distance from 1 and 9
# Distance from 1 and 10
# Distance from 1 and 11
# Distance from 1 and 12
# Distance from 1 and 13
# Distance from 1 and 14
# Distance from 1 and 15
# Distance from 1 and 16
# Distance from 1 and 17
# Distance from 1 and 18
# Distance from 1 and 19
# Distance from 1 and 20
# Distance from 1 and 21
# Distance from 1 and 22
# Distance from 1 and 23
# Distance from 1 and 24
# Distance from 1 and 25
# Distance from 1 and 26
# Distance from 1 and 27
# Distance from 1 and 28
# Distance from 1 and 29
# Distance from 1 and 30
# Distance from 1 and 31
# Distance from 1 and 32
# Distance from 1 and 33
# Distance from 1 and 34
# Distance from 1 and 35
# Distance from 1 and 36
# Distance from 1 and 37
# Distance from 1 and 38
# Distance from 1 and 39
# Distance from 1 and 40
# Distance from 1 and 41
# Distance from 1 and 42
# Distance from 1 and 43
# Distance from 1 and 44
# Distance from 1 and 45
# Distance from 1 and 46
# Distance from 1 and 47
# Distance from 1 and 48
# Distance from 1 and 49
# Distance from 1 and 50
# Distance from 1 and 51
# Distance from 1 and 52
# Distance from 1 and 53
# Distance from 1 and 54
# Distance from 1 and 55
# Distance from 1 and 56
# Distance from 1 and 57
# Distance from 1 and 58
# Distance from 1 and 59
# Distance from 1 and 60
# Distance from 1 and 61
# Distance from 1 and 62
# Distance from 1 and 63
# Distance from 1 and 64
# Distance from 1 and 65
# Distance from 1 and 66
# Distance from 1 and 67
# Distance from 1 and 68
# Distance from 1 and 69
# Distance from 1 and 70
# Distance from 1 and 71
# Distance from 1 and 72
# Distance from 1 and 73
# Distance from 1 and 74
# Distance from 1 and 75
# Distance from 1 and 76
# Distance from 1 and 77
# Distance from 1 and 78
# Distance from 1 and 79
# Distance from 1 and 80
# Distance from 1 and 81
# Distance from 1 and 82
# Distance from 1 and 83
# Distance from 1 and 84
# Distance from 1 and 85
# Distance from 1 and 86
# Distance from 1 and 87
# Distance from 1 and 88
# Distance from 1 and 89
# Distance from 2 and 0
# Distance from 2 and 1
# Distance from 2 and 2
# Distance from 2 and 3
# Distance from 2 and 4
# Distance from 2 and 5
# Distance from 2 and 6
# Distance from 2 and 7
# Distance from 2 and 8
# Distance from 2 and 9
# Distance from 2 and 10
# Distance from 2 and 11
# Distance from 2 and 12
# Distance from 2 and 13
# Distance from 2 and 14
# Distance from 2 and 15
# Distance from 2 and 16
# Distance from 2 and 17
# Distance from 2 and 18
# Distance from 2 and 19
# Distance from 2 and 20
# Distance from 2 and 21
# Distance from 2 and 22
# Distance from 2 and 23
# Distance from 2 and 24
# Distance from 2 and 25
# Distance from 2 and 26
# Distance from 2 and 27
# Distance from 2 and 28
# Distance from 2 and 29
# Distance from 2 and 30
# Distance from 2 and 31
# Distance from 2 and 32
# Distance from 2 and 33
# Distance from 2 and 34
# Distance from 2 and 35
# Distance from 2 and 36
# Distance from 2 and 37
# Distance from 2 and 38
# Distance from 2 and 39
# Distance from 2 and 40
# Distance from 2 and 41
# Distance from 2 and 42
# Distance from 2 and 43
# Distance from 2 and 44
# Distance from 2 and 45
# Distance from 2 and 46
# Distance from 2 and 47
# Distance from 2 and 48
# Distance from 2 and 49
# Distance from 2 and 50
# Distance from 2 and 51
# Distance from 2 and 52
# Distance from 2 and 53
# Distance from 2 and 54
# Distance from 2 and 55
# Distance from 2 and 56
# Distance from 2 and 57
# Distance from 2 and 58
# Distance from 2 and 59
# Distance from 2 and 60
# Distance from 2 and 61
# Distance from 2 and 62
# Distance from 2 and 63
# Distance from 2 and 64
# Distance from 2 and 65
# Distance from 2 and 66
# Distance from 2 and 67
# Distance from 2 and 68
# Distance from 2 and 69
# Distance from 2 and 70
# Distance from 2 and 71
# Distance from 2 and 72
# Distance from 2 and 73
# Distance from 2 and 74
# Distance from 2 and 75
# Distance from 2 and 76
# Distance from 2 and 77
# Distance from 2 and 78
# Distance from 2 and 79
# Distance from 2 and 80
# Distance from 2 and 81
# Distance from 2 and 82
# Distance from 2 and 83
# Distance from 2 and 84
# Distance from 2 and 85
# Distance from 2 and 86
# Distance from 2 and 87
# Distance from 2 and 88
# Distance from 2 and 89
# Distance from 3 and 0
# Distance from 3 and 1
# Distance from 3 and 2
# Distance from 3 and 3
# Distance from 3 and 4
# Distance from 3 and 5
# Distance from 3 and 6
# Distance from 3 and 7
# Distance from 3 and 8
# Distance from 3 and 9
# Distance from 3 and 10
# Distance from 3 and 11
# Distance from 3 and 12
# Distance from 3 and 13
# Distance from 3 and 14
# Distance from 3 and 15
# Distance from 3 and 16
# Distance from 3 and 17
# Distance from 3 and 18
# Distance from 3 and 19
# Distance from 3 and 20
# Distance from 3 and 21
# Distance from 3 and 22
# Distance from 3 and 23
# Distance from 3 and 24
# Distance from 3 and 25
# Distance from 3 and 26
# Distance from 3 and 27
# Distance from 3 and 28
# Distance from 3 and 29
# Distance from 3 and 30
# Distance from 3 and 31
# Distance from 3 and 32
# Distance from 3 and 33
# Distance from 3 and 34
# Distance from 3 and 35
# Distance from 3 and 36
# Distance from 3 and 37
# Distance from 3 and 38
# Distance from 3 and 39
# Distance from 3 and 40
# Distance from 3 and 41
# Distance from 3 and 42
# Distance from 3 and 43
# Distance from 3 and 44
# Distance from 3 and 45
# Distance from 3 and 46
# Distance from 3 and 47
# Distance from 3 and 48
# Distance from 3 and 49
# Distance from 3 and 50
# Distance from 3 and 51
# Distance from 3 and 52
# Distance from 3 and 53
# Distance from 3 and 54
# Distance from 3 and 55
# Distance from 3 and 56
# Distance from 3 and 57
# Distance from 3 and 58
# Distance from 3 and 59
# Distance from 3 and 60
# Distance from 3 and 61
# Distance from 3 and 62
# Distance from 3 and 63
# Distance from 3 and 64
# Distance from 3 and 65
# Distance from 3 and 66
# Distance from 3 and 67
# Distance from 3 and 68
# Distance from 3 and 69
# Distance from 3 and 70
# Distance from 3 and 71
# Distance from 3 and 72
# Distance from 3 and 73
# Distance from 3 and 74
# Distance from 3 and 75
# Distance from 3 and 76
# Distance from 3 and 77
# Distance from 3 and 78
# Distance from 3 and 79
# Distance from 3 and 80
# Distance from 3 and 81
# Distance from 3 and 82
# Distance from 3 and 83
# Distance from 3 and 84
# Distance from 3 and 85
# Distance from 3 and 86
# Distance from 3 and 87
# Distance from 3 and 88
# Distance from 3 and 89
# Distance from 4 and 0
# Distance from 4 and 1
# Distance from 4 and 2
# Distance from 4 and 3
# Distance from 4 and 4
# Distance from 4 and 5
# Distance from 4 and 6
# Distance from 4 and 7
# Distance from 4 and 8
# Distance from 4 and 9
# Distance from 4 and 10
# Distance from 4 and 11
# Distance from 4 and 12
# Distance from 4 and 13
# Distance from 4 and 14
# Distance from 4 and 15
# Distance from 4 and 16
# Distance from 4 and 17
# Distance from 4 and 18
# Distance from 4 and 19
# Distance from 4 and 20
# Distance from 4 and 21
# Distance from 4 and 22
# Distance from 4 and 23
# Distance from 4 and 24
# Distance from 4 and 25
# Distance from 4 and 26
# Distance from 4 and 27
# Distance from 4 and 28
# Distance from 4 and 29
# Distance from 4 and 30
# Distance from 4 and 31
# Distance from 4 and 32
# Distance from 4 and 33
# Distance from 4 and 34
# Distance from 4 and 35
# Distance from 4 and 36
# Distance from 4 and 37
# Distance from 4 and 38
# Distance from 4 and 39
# Distance from 4 and 40
# Distance from 4 and 41
# Distance from 4 and 42
# Distance from 4 and 43
# Distance from 4 and 44
# Distance from 4 and 45
# Distance from 4 and 46
# Distance from 4 and 47
# Distance from 4 and 48
# Distance from 4 and 49
# Distance from 4 and 50
# Distance from 4 and 51
# Distance from 4 and 52
# Distance from 4 and 53
# Distance from 4 and 54
# Distance from 4 and 55
# Distance from 4 and 56
# Distance from 4 and 57
# Distance from 4 and 58
# Distance from 4 and 59
# Distance from 4 and 60
# Distance from 4 and 61
# Distance from 4 and 62
# Distance from 4 and 63
# Distance from 4 and 64
# Distance from 4 and 65
# Distance from 4 and 66
# Distance from 4 and 67
# Distance from 4 and 68
# Distance from 4 and 69
# Distance from 4 and 70
# Distance from 4 and 71
# Distance from 4 and 72
# Distance from 4 and 73
# Distance from 4 and 74
# Distance from 4 and 75
# Distance from 4 and 76
# Distance from 4 and 77
# Distance from 4 and 78
# Distance from 4 and 79
# Distance from 4 and 80
# Distance from 4 and 81
# Distance from 4 and 82
# Distance from 4 and 83
# Distance from 4 and 84
# Distance from 4 and 85
# Distance from 4 and 86
# Distance from 4 and 87
# Distance from 4 and 88
# Distance from 4 and 89
# Distance from 5 and 0
# Distance from 5 and 1
# Distance from 5 and 2
# Distance from 5 and 3
# Distance from 5 and 4
# Distance from 5 and 5
# Distance from 5 and 6
# Distance from 5 and 7
# Distance from 5 and 8
# Distance from 5 and 9
# Distance from 5 and 10
# Distance from 5 and 11
# Distance from 5 and 12
# Distance from 5 and 13
# Distance from 5 and 14
# Distance from 5 and 15
# Distance from 5 and 16
# Distance from 5 and 17
# Distance from 5 and 18
# Distance from 5 and 19
# Distance from 5 and 20
# Distance from 5 and 21
# Distance from 5 and 22
# Distance from 5 and 23
# Distance from 5 and 24
# Distance from 5 and 25
# Distance from 5 and 26
# Distance from 5 and 27
# Distance from 5 and 28
# Distance from 5 and 29
# Distance from 5 and 30
# Distance from 5 and 31
# Distance from 5 and 32
# Distance from 5 and 33
# Distance from 5 and 34
# Distance from 5 and 35
# Distance from 5 and 36
# Distance from 5 and 37
# Distance from 5 and 38
# Distance from 5 and 39
# Distance from 5 and 40
# Distance from 5 and 41
# Distance from 5 and 42
# Distance from 5 and 43
# Distance from 5 and 44
# Distance from 5 and 45
# Distance from 5 and 46
# Distance from 5 and 47
# Distance from 5 and 48
# Distance from 5 and 49
# Distance from 5 and 50
# Distance from 5 and 51
# Distance from 5 and 52
# Distance from 5 and 53
# Distance from 5 and 54
# Distance from 5 and 55
# Distance from 5 and 56
# Distance from 5 and 57
# Distance from 5 and 58
# Distance from 5 and 59
# Distance from 5 and 60
# Distance from 5 and 61
# Distance from 5 and 62
# Distance from 5 and 63
# Distance from 5 and 64
# Distance from 5 and 65
# Distance from 5 and 66
# Distance from 5 and 67
# Distance from 5 and 68
# Distance from 5 and 69
# Distance from 5 and 70
# Distance from 5 and 71
# Distance from 5 and 72
# Distance from 5 and 73
# Distance from 5 and 74
# Distance from 5 and 75
# Distance from 5 and 76
# Distance from 5 and 77
# Distance from 5 and 78
# Distance from 5 and 79
# Distance from 5 and 80
# Distance from 5 and 81
# Distance from 5 and 82
# Distance from 5 and 83
# Distance from 5 and 84
# Distance from 5 and 85
# Distance from 5 and 86
# Distance from 5 and 87
# Distance from 5 and 88
# Distance from 5 and 89
# Distance from 6 and 0
# Distance from 6 and 1
# Distance from 6 and 2
# Distance from 6 and 3
# Distance from 6 and 4
# Distance from 6 and 5
# Distance from 6 and 6
# Distance from 6 and 7
# Distance from 6 and 8
# Distance from 6 and 9
# Distance from 6 and 10
# Distance from 6 and 11
# Distance from 6 and 12
# Distance from 6 and 13
# Distance from 6 and 14
# Distance from 6 and 15
# Distance from 6 and 16
# Distance from 6 and 17
# Distance from 6 and 18
# Distance from 6 and 19
# Distance from 6 and 20
# Distance from 6 and 21
# Distance from 6 and 22
# Distance from 6 and 23
# Distance from 6 and 24
# Distance from 6 and 25
# Distance from 6 and 26
# Distance from 6 and 27
# Distance from 6 and 28
# Distance from 6 and 29
# Distance from 6 and 30
# Distance from 6 and 31
# Distance from 6 and 32
# Distance from 6 and 33
# Distance from 6 and 34
# Distance from 6 and 35
# Distance from 6 and 36
# Distance from 6 and 37
# Distance from 6 and 38
# Distance from 6 and 39
# Distance from 6 and 40
# Distance from 6 and 41
# Distance from 6 and 42
# Distance from 6 and 43
# Distance from 6 and 44
# Distance from 6 and 45
# Distance from 6 and 46
# Distance from 6 and 47
# Distance from 6 and 48
# Distance from 6 and 49
# Distance from 6 and 50
# Distance from 6 and 51
# Distance from 6 and 52
# Distance from 6 and 53
# Distance from 6 and 54
# Distance from 6 and 55
# Distance from 6 and 56
# Distance from 6 and 57
# Distance from 6 and 58
# Distance from 6 and 59
# Distance from 6 and 60
# Distance from 6 and 61
# Distance from 6 and 62
# Distance from 6 and 63
# Distance from 6 and 64
# Distance from 6 and 65
# Distance from 6 and 66
# Distance from 6 and 67
# Distance from 6 and 68
# Distance from 6 and 69
# Distance from 6 and 70
# Distance from 6 and 71
# Distance from 6 and 72
# Distance from 6 and 73
# Distance from 6 and 74
# Distance from 6 and 75
# Distance from 6 and 76
# Distance from 6 and 77
# Distance from 6 and 78
# Distance from 6 and 79
# Distance from 6 and 80
# Distance from 6 and 81
# Distance from 6 and 82
# Distance from 6 and 83
# Distance from 6 and 84
# Distance from 6 and 85
# Distance from 6 and 86
# Distance from 6 and 87
# Distance from 6 and 88
# Distance from 6 and 89
# Distance from 7 and 0
# Distance from 7 and 1
# Distance from 7 and 2
# Distance from 7 and 3
# Distance from 7 and 4
# Distance from 7 and 5
# Distance from 7 and 6
# Distance from 7 and 7
# Distance from 7 and 8
# Distance from 7 and 9
# Distance from 7 and 10
# Distance from 7 and 11
# Distance from 7 and 12
# Distance from 7 and 13
# Distance from 7 and 14
# Distance from 7 and 15
# Distance from 7 and 16
# Distance from 7 and 17
# Distance from 7 and 18
# Distance from 7 and 19
# Distance from 7 and 20
# Distance from 7 and 21
# Distance from 7 and 22
# Distance from 7 and 23
# Distance from 7 and 24
# Distance from 7 and 25
# Distance from 7 and 26
# Distance from 7 and 27
# Distance from 7 and 28
# Distance from 7 and 29
# Distance from 7 and 30
# Distance from 7 and 31
# Distance from 7 and 32
# Distance from 7 and 33
# Distance from 7 and 34
# Distance from 7 and 35
# Distance from 7 and 36
# Distance from 7 and 37
# Distance from 7 and 38
# Distance from 7 and 39
# Distance from 7 and 40
# Distance from 7 and 41
# Distance from 7 and 42
# Distance from 7 and 43
# Distance from 7 and 44
# Distance from 7 and 45
# Distance from 7 and 46
# Distance from 7 and 47
# Distance from 7 and 48
# Distance from 7 and 49
# Distance from 7 and 50
# Distance from 7 and 51
# Distance from 7 and 52
# Distance from 7 and 53
# Distance from 7 and 54
# Distance from 7 and 55
# Distance from 7 and 56
# Distance from 7 and 57
# Distance from 7 and 58
# Distance from 7 and 59
# Distance from 7 and 60
# Distance from 7 and 61
# Distance from 7 and 62
# Distance from 7 and 63
# Distance from 7 and 64
# Distance from 7 and 65
# Distance from 7 and 66
# Distance from 7 and 67
# Distance from 7 and 68
# Distance from 7 and 69
# Distance from 7 and 70
# Distance from 7 and 71
# Distance from 7 and 72
# Distance from 7 and 73
# Distance from 7 and 74
# Distance from 7 and 75
# Distance from 7 and 76
# Distance from 7 and 77
# Distance from 7 and 78
# Distance from 7 and 79
# Distance from 7 and 80
# Distance from 7 and 81
# Distance from 7 and 82
# Distance from 7 and 83
# Distance from 7 and 84
# Distance from 7 and 85
# Distance from 7 and 86
# Distance from 7 and 87
# Distance from 7 and 88
# Distance from 7 and 89

# %%
from sklearn.metrics import classification_report, confusion_matrix

conf_mat = confusion_matrix(label, y_test)
##TODO: Visualize the confusion matrix
